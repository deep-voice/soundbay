# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import soundfile as sf
from pathlib import Path
import re
import os
import json

# %% [markdown]
# ## Annotation DB

# %% [markdown]
# ### define paths for annotations and audio files

# %%
selection_path = Path('../../../../multispecies_dataset')
filelist = list(selection_path.glob('**/*.csv'))
# variables_names = [x.name.split('.')[0] for x in files_list]
filelist
# Out:
# [PosixPath('../../../../multispecies_dataset/HYDBBA105_Calls_2018_04_2kHz.csv'),
#  PosixPath('../../../../multispecies_dataset/HYDBBA105_Calls_2018_04_EvenDays_MF.csv'),
#  PosixPath('../../../../multispecies_dataset/HYDBBA105_Calls_2018_04_200Hz.csv'),
#  PosixPath('../../../../multispecies_dataset/HYDBBA105_AcousticEvents_2018_04_EvenDays_AllRuns_v2.csv')]

# %% [markdown]
# ### parse .csv file into pandas df

# %%
metadata =[]
for i,file in enumerate(filelist):
    dfTemp = pd.read_csv(file)
    print(file)
    print(dfTemp.columns)
    print(dfTemp.shape)
#     dfTemp['filename'] = re.search(r'18\d{4,4}_\d{6,6}', file.as_posix()).group() 
#     dfTemp['StartMicInWater'] =np.amin(dfTemp['Begin Time (s)'])
#     dfTemp['EndMicInWater'] =np.amax(dfTemp['End Time (s)'])
    metadata.append(dfTemp)

# metadata = pd.concat(metadata)
# metadata.rename(columns={'Begin Time (s)': 'begin_time', 'End Time (s)': 'end_time'}, inplace=True)
# Out:
# ../../../../multispecies_dataset/HYDBBA105_Calls_2018_04_2kHz.csv
# Index(['Id', 'UID', 'UTC', 'UTCMilliseconds', 'parentID', 'parentUID',
#        'LongDataName', 'BinaryFile'],
#       dtype='object')
# (10424, 8)
# ../../../../multispecies_dataset/HYDBBA105_Calls_2018_04_EvenDays_MF.csv
# Index(['Id', 'UID', 'UTC', 'UTCMilliseconds', 'PCLocalTime', 'PCTime',
#        'ChannelBitmap', 'SequenceBitmap', 'parentID', 'parentUID',
#        'LongDataName', 'BinaryFile'],
#       dtype='object')
# (600331, 12)
# ../../../../multispecies_dataset/HYDBBA105_Calls_2018_04_200Hz.csv
# Index(['Id', 'UID', 'UTC', 'UTCMilliseconds', 'parentID', 'parentUID',
#        'LongDataName', 'BinaryFile'],
#       dtype='object')
# (4802, 8)
# ../../../../multispecies_dataset/HYDBBA105_AcousticEvents_2018_04_EvenDays_AllRuns_v2.csv
# Index(['Run', 'ID', 'PG_UID', 'UTC', 'UTCMilliseconds', 'EndTime', 'DataCount',
#        'Analyst', 'Species_ID', 'Sound_type', 'Comments', 'Unnamed: 11'],
#       dtype='object')
# (136, 12)

# %%
Calls_2018_04_2kHz, Calls_2018_04_EvenDays_MF, Calls_2018_04_200Hz,EvenDays_AllRuns_v2 = metadata

# %%
Calls_2018_04_2kHz.head()
# Out:
#    Id       UID                UTC  UTCMilliseconds  parentID  parentUID  \
# 0   1  46000050  4/2/2018 17:45:38              791         1          1
# 1   2  46000051  4/2/2018 17:46:02              759         1          1
# 2   3  46000057  4/2/2018 17:51:01              183         1          1
# 3   4  46000058  4/2/2018 17:51:15              359         1          1
# 4   5  46000059  4/2/2018 17:51:29              830         1          1
#
#                                         LongDataName  \
# 0  Whistle and Moan Detector, Contours           ...
# 1  Whistle and Moan Detector, Contours           ...
# 2  Whistle and Moan Detector, Contours           ...
# 3  Whistle and Moan Detector, Contours           ...
# 15  2018-04-02 09:42:14.300  2020-12-16 05:50:33.866              1
# 16  2018-04-02 09:42:14.306  2020-12-16 05:50:33.866              1
# 17  2018-04-02 09:42:14.308  2020-12-16 05:50:33.866              1
# 18  2018-04-02 09:42:16.448  2020-12-16 05:50:33.866              1
# 19  2018-04-02 09:42:16.453  2020-12-16 05:50:33.866              1
#
#     SequenceBitmap  parentID  parentUID            LongDataName  \
# 0              NaN         1          1  Click Detector, Clicks
# 1              NaN         1          1  Click Detector, Clicks
# 2              NaN         1          1  Click Detector, Clicks
# 3              NaN         1          1  Click Detector, Clicks
# 4              NaN         1          1  Click Detector, Clicks
# 5              NaN         1          1  Click Detector, Clicks
# 6              NaN         1          1  Click Detector, Clicks
# 7              NaN         1          1  Click Detector, Clicks
# 8              NaN         1          1  Click Detector, Clicks
# 9              NaN         1          1  Click Detector, Clicks
# 10             NaN         1          1  Click Detector, Clicks
# 11             NaN         1          1  Click Detector, Clicks
# 12             NaN         1          1  Click Detector, Clicks
# 13             NaN         1          1  Click Detector, Clicks
# 14             NaN         1          1  Click Detector, Clicks
# 15             NaN         1          1  Click Detector, Clicks
# 16             NaN         1          1  Click Detector, Clicks
# 17             NaN         1          1  Click Detector, Clicks
# 18             NaN         1          1  Click Detector, Clicks
# 19             NaN         1          1  Click Detector, Clicks
#
#                                            BinaryFile
# 0   Click_Detector_Click_Detector_Clicks_20180402_...
# 1   Click_Detector_Click_Detector_Clicks_20180402_...
# 2   Click_Detector_Click_Detector_Clicks_20180402_...
# 3   Click_Detector_Click_Detector_Clicks_20180402_...
# 4   Click_Detector_Click_Detector_Clicks_20180402_...
# 5   Click_Detector_Click_Detector_Clicks_20180402_...
# 6   Click_Detector_Click_Detector_Clicks_20180402_...
# 7   Click_Detector_Click_Detector_Clicks_20180402_...
# 8   Click_Detector_Click_Detector_Clicks_20180402_...
# 9   Click_Detector_Click_Detector_Clicks_20180402_...
# 10  Click_Detector_Click_Detector_Clicks_20180402_...
# 11  Click_Detector_Click_Detector_Clicks_20180402_...
# 12  Click_Detector_Click_Detector_Clicks_20180402_...
# 13  Click_Detector_Click_Detector_Clicks_20180402_...
# 14  Click_Detector_Click_Detector_Clicks_20180402_...
# 15  Click_Detector_Click_Detector_Clicks_20180402_...
# 16  Click_Detector_Click_Detector_Clicks_20180402_...
# 17  Click_Detector_Click_Detector_Clicks_20180402_...
# 18  Click_Detector_Click_Detector_Clicks_20180402_...
# 19  Click_Detector_Click_Detector_Clicks_20180402_...

# %% [markdown]
# ### For Calls_2018_04_2kHz and Calls_2018_04_200Hz
# * ParentID and parentUID are duplicated columns, Id and UID are similar
# * * probably need only one of the mentioned 4 columns since they hold unique values
# * * * LongDataName non unique - to get rid of
#
# ### For Calls_2018_04_EvenDays_MF
# * ChannelBitmap and SequenceBitmap seems to be irrelevant with no meaningful values.
# * * Same remarks as for Calls_2018_04_2kHz and Calls_2018_04_200Hz
# * * * LongDataName could be meaningful - seperating between clicks and whistles and moans
#
# ### For EvenDays_AllRuns_v2
# * Unnamed: 11 seems to be irrelevant with no meaningful values.
# * * Same remarks as for Calls_2018_04_2kHz and Calls_2018_04_200Hz

# %%
combined_annotations.to_csv('combined_annotations.csv', index=False)
